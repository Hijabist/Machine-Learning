# %% [markdown]
# # **Import Library**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Downgrade agar tidak conflict dengan tfjs
# !pip install packaging==23.1 -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 2.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-bigquery 3.33.0 requires packaging>=24.2.0, but you have packaging 23.1 which is incompatible.
# xarray 2025.3.1 requires packaging>=23.2, but you have packaging 23.1 which is incompatible.
# langchain-core 0.3.60 requires packaging<25,>=23.2, but you have packaging 23.1 which is incompatible.
# db-dtypes 1.4.3 requires packaging>=24.2.0, but you have packaging 23.1 which is incompatible.
# langsmith 0.3.42 requires packaging>=23.2, but you have packaging 23.1 which is incompatible.

# %%
# !pip install tensorflow==2.18.0 tensorflowjs -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 kB 5.2 MB/s eta 0:00:00

# %%
import tensorflow as tf
import os
import shutil
import zipfile

# %% [markdown]
# # **Load Model**

# %%
model_path = '/content/drive/MyDrive/Hijabist-Drive/Skin-tone/Model keras/Skin-tone-model.keras'

# Load model
model = tf.keras.models.load_model(model_path)

# %%
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1 (Conv2D)                  │ (None, 112, 112, 32)   │           864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1_bn (BatchNormalization)   │ (None, 112, 112, 32)   │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1_relu (ReLU)               │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_1 (DepthwiseConv2D)     │ (None, 112, 112, 32)   │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_1_bn                    │ (None, 112, 112, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_1_relu (ReLU)           │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_1 (Conv2D)              │ (None, 112, 112, 64)   │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_1_bn                    │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_1_relu (ReLU)           │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pad_2 (ZeroPadding2D)      │ (None, 113, 113, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_2 (DepthwiseConv2D)     │ (None, 56, 56, 64)     │           576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_2_bn                    │ (None, 56, 56, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_2_relu (ReLU)           │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_2 (Conv2D)              │ (None, 56, 56, 128)    │         8,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_2_bn                    │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_2_relu (ReLU)           │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_3 (DepthwiseConv2D)     │ (None, 56, 56, 128)    │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_3_bn                    │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_3_relu (ReLU)           │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_3 (Conv2D)              │ (None, 56, 56, 128)    │        16,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_3_bn                    │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_3_relu (ReLU)           │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pad_4 (ZeroPadding2D)      │ (None, 57, 57, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_4 (DepthwiseConv2D)     │ (None, 28, 28, 128)    │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_4_bn                    │ (None, 28, 28, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_4_relu (ReLU)           │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_4 (Conv2D)              │ (None, 28, 28, 256)    │        32,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_4_bn                    │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_4_relu (ReLU)           │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_5 (DepthwiseConv2D)     │ (None, 28, 28, 256)    │         2,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_5_bn                    │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_5_relu (ReLU)           │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_5 (Conv2D)              │ (None, 28, 28, 256)    │        65,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_5_bn                    │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_5_relu (ReLU)           │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pad_6 (ZeroPadding2D)      │ (None, 29, 29, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_6 (DepthwiseConv2D)     │ (None, 14, 14, 256)    │         2,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_6_bn                    │ (None, 14, 14, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_6_relu (ReLU)           │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_6 (Conv2D)              │ (None, 14, 14, 512)    │       131,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_6_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_6_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_7 (DepthwiseConv2D)     │ (None, 14, 14, 512)    │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_7_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_7_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_7 (Conv2D)              │ (None, 14, 14, 512)    │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_7_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_7_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_8 (DepthwiseConv2D)     │ (None, 14, 14, 512)    │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_8_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_8_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_8 (Conv2D)              │ (None, 14, 14, 512)    │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_8_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_8_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_9 (DepthwiseConv2D)     │ (None, 14, 14, 512)    │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_9_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_9_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_9 (Conv2D)              │ (None, 14, 14, 512)    │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_9_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_9_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_10 (DepthwiseConv2D)    │ (None, 14, 14, 512)    │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_10_bn                   │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_10_relu (ReLU)          │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_10 (Conv2D)             │ (None, 14, 14, 512)    │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_10_bn                   │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_10_relu (ReLU)          │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_11 (DepthwiseConv2D)    │ (None, 14, 14, 512)    │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_11_bn                   │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_11_relu (ReLU)          │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_11 (Conv2D)             │ (None, 14, 14, 512)    │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_11_bn                   │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_11_relu (ReLU)          │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pad_12 (ZeroPadding2D)     │ (None, 15, 15, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_12 (DepthwiseConv2D)    │ (None, 7, 7, 512)      │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_12_bn                   │ (None, 7, 7, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_12_relu (ReLU)          │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_12 (Conv2D)             │ (None, 7, 7, 1024)     │       524,288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_12_bn                   │ (None, 7, 7, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_12_relu (ReLU)          │ (None, 7, 7, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_13 (DepthwiseConv2D)    │ (None, 7, 7, 1024)     │         9,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_13_bn                   │ (None, 7, 7, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_13_relu (ReLU)          │ (None, 7, 7, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_13 (Conv2D)             │ (None, 7, 7, 1024)     │     1,048,576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_13_bn                   │ (None, 7, 7, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_13_relu (ReLU)          │ (None, 7, 7, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_3      │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,530,254 (40.17 MB)
#  Trainable params: 3,502,788 (13.36 MB)
#  Non-trainable params: 21,888 (85.50 KB)
#  Optimizer params: 7,005,578 (26.72 MB)

# %% [markdown]
# # **Konversi ke Saved_model**

# %%
# Konversi ke Saved_Model
model.export('/content/saved_model_ST/1')
# Out:
# Saved artifact at '/content/saved_model_ST/1'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_3')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   136153333443728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153333446992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153333447184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153333444688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153333447760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153333447952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153333448336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153333444496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153333448528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153333446416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153333447568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329977104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329975760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329976144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329975952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329978256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329979984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329980368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329980176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329978832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329981520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329981136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329980752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329981712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329979600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329983824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329984208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329984592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329984400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329979216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329985744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329986128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329986512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329986320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329982672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329987664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329988048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329988432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329988240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329983440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329985360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329990160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329990544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329990352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329986896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329989584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286279824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286280208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329991312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153329989200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286281360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286281744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286282128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286281936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286279248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286283280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286283664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286284048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286283856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286279632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286285200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286285584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286285968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286285776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286280976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286287120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286287504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286287888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286287696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286282896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286289040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286289424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286289808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286289616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286284816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286290960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286291344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286291728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286291536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286286736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286292880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286293264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286293648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286293456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286288656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286294800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286295376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286294032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286295184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286292496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286656272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286657616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286658000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286657808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286657232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286659152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286659536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286659920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286659728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286656464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286661072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286661456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286661840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286661648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286656656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286662992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286663376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286663760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286663568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286658768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286664912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286665296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286665680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286665488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286660688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286666832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286667216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286667600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286667408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286662608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286668752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286669136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286669520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286669328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286664528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286670672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286671056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286671440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286671248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286666448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286669904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153287049872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153287049296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286672208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153286668368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153287050256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153287052368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153287051600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153287053520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153287052752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136153287054672: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
# !zip -r saved_model_ST.zip /content/saved_model_ST
# Out:
#   adding: content/saved_model_ST/ (stored 0%)
#   adding: content/saved_model_ST/1/ (stored 0%)
#   adding: content/saved_model_ST/1/saved_model.pb (deflated 90%)
#   adding: content/saved_model_ST/1/variables/ (stored 0%)
#   adding: content/saved_model_ST/1/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: content/saved_model_ST/1/variables/variables.index (deflated 78%)
#   adding: content/saved_model_ST/1/fingerprint.pb (stored 0%)
#   adding: content/saved_model_ST/1/assets/ (stored 0%)

# %% [markdown]
# # **Konversi ke TFJS**

# %%
# Konversi Saved_Model ke TensorFlow.js
# !tensorflowjs_converter \
    --input_format=tf_saved_model \
    /content/saved_model_ST/1 \
    /content/modeltfjs_ST

print("Model berhasil dikonversi ke TensorFlow.js.")
# Out:
# 2025-05-30 13:45:21.075591: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748612721.100701     971 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748612721.108667     971 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 🌲 Try https://ydf.readthedocs.io, the successor of TensorFlow Decision Forests with more features and faster training!
# 2025-05-30 13:45:28.952563: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# I0000 00:00:1748612729.679955     971 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1748612729.680185     971 single_machine.cc:361] Starting new session
# Model berhasil dikonversi ke TensorFlow.js.

# %%
# !zip -r model_tfjs_ST.zip /content/modeltfjs_ST
# Out:
#   adding: content/modeltfjs_ST/ (stored 0%)
#   adding: content/modeltfjs_ST/model.json (deflated 95%)
#   adding: content/modeltfjs_ST/group1-shard3of4.bin (deflated 7%)
#   adding: content/modeltfjs_ST/group1-shard4of4.bin (deflated 8%)
#   adding: content/modeltfjs_ST/group1-shard2of4.bin (deflated 7%)
#   adding: content/modeltfjs_ST/group1-shard1of4.bin (deflated 7%)

# %% [markdown]
# # **Konversi ke TFlite (Opsional)**

# %%
# Konversi Saved_Model ke format TFLite
save_path = '/content/saved_model_ST/1'
converter = tf.lite.TFLiteConverter.from_saved_model(save_path)
tflite_model = converter.convert()
with tf.io.gfile.GFile('/content/model_ST.tflite', 'wb') as f:
    f.write(tflite_model)

print("Model berhasil dikonversi ke TFLite dan disimpan sebagai model_ST.tflite")
# Out:
# Model berhasil dikonversi ke TFLite dan disimpan sebagai model_ST.tflite

# %% [markdown]
# # **Copy to drive**

# %%
# Definisikan path ke file zip
files_to_copy = ["saved_model_ST.zip", "model_tfjs_ST.zip", "model_ST.tflite"]

# Inisialisasi folder Google Drive
destination_folder = '/content/drive/MyDrive/Hijabist-Drive/Skin-tone/Model-Convert/'
os.makedirs(destination_folder, exist_ok=True)

# Salin setiap file zip ke Google Drive
for zip_file_path in files_to_copy:
  destination_path = os.path.join(destination_folder, os.path.basename(zip_file_path))
  try:
    shutil.copy(zip_file_path, destination_path)
    print(f"'{zip_file_path}' disalin ke '{destination_path}'")
  except FileNotFoundError:
    print(f"Error: '{zip_file_path}' tidak ditemukan.")
  except Exception as e:
    print(f"Terjadi error saat menyalin '{zip_file_path}': {e}")
# Out:
# 'saved_model_ST.zip' disalin ke '/content/drive/MyDrive/Hijabist-Drive/Skin-tone/Model-Convert/saved_model_ST.zip'
# 'model_tfjs_ST.zip' disalin ke '/content/drive/MyDrive/Hijabist-Drive/Skin-tone/Model-Convert/model_tfjs_ST.zip'
# 'model_ST.tflite' disalin ke '/content/drive/MyDrive/Hijabist-Drive/Skin-tone/Model-Convert/model_ST.tflite'
